# %%
from sagemaker.sklearn import SKLearn

# %%
sklearn_estimator = SKLearn('iris_train.py',
                            instance_type='ml.m4.xlarge',
                            role='LabRole',
                            framework_version='0.20.0',
                            )
sklearn_estimator.fit({'train': 's3://ia-dataset-jrcc/data/train',
                        'test': 's3://ia-dataset-jrcc/data/test'})
# Out:
# 2022-05-21 00:09:03 Starting - Starting the training job...
# 2022-05-21 00:09:30 Starting - Preparing the instances for trainingProfilerReport-1653091742: InProgress
# ............
# 2022-05-21 00:11:27 Downloading - Downloading input data...
# 2022-05-21 00:11:53 Training - Downloading the training image......
# 2022-05-21 00:12:59 Uploading - Uploading generated training model2022-05-21 00:12:52,198 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2022-05-21 00:12:52,201 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-05-21 00:12:52,215 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2022-05-21 00:12:52,855 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-05-21 00:12:52,872 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# ...
